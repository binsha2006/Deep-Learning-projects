# %%
import torch
import torch.nn as nn
import torch.optim as optim
x = torch.tensor([[1.0], [2.0], [3.0], [4.0]])
y = 3 * x - 2
model = nn.Linear(1, 1)
loss_function = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)
for epoch in range(300):
    prediction = model(x)
    loss = loss_function(prediction, y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    if (epoch + 1) % 50 == 0:
        print("Epoch:", epoch + 1)
        print("Loss:", loss.item())
test_x = torch.tensor([[10.0]])
predicted_y = model(test_x)
print("\nPrediction for x = 10:")
print(predicted_y.item())
# Out:
# Epoch: 50
# Loss: 1.327505350112915
# Epoch: 100
# Loss: 0.9835975766181946
# Epoch: 150
# Loss: 0.7287840843200684
# Epoch: 200
# Loss: 0.5399833917617798
# Epoch: 250
# Loss: 0.4000937342643738
# Epoch: 300
# Loss: 0.29644444584846497
#
# Prediction for x = 10:
# 24.81046485900879
