# %%
# !pip install langchain langchain-community
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
import pandas as pd
text = """
Artificial Intelligence is transforming industries around the world.
Machine Learning allows computers to learn patterns from data.
Deep Learning is a subset of machine learning using neural networks.
Natural Language Processing helps machines understand human language.
Computer Vision enables machines to analyze images and videos.
Python is one of the most popular programming languages in AI.
Data preprocessing is important before training ML models.
Neural Networks are inspired by the structure of the human brain.
Large Language Models are capable of generating human-like text.
AI applications include healthcare, finance, education, and robotics.
"""
with open("sample.txt", "w", encoding="utf-8") as file:
    file.write(text)
loader = TextLoader("sample.txt")
documents = loader.load()
chunk_sizes = [200, 500, 1000]
for size in chunk_sizes:
    print("\n" + "=" * 60)
    print(f"CHUNK SIZE = {size}")
    print("=" * 60)
    splitter = RecursiveCharacterTextSplitter(
        chunk_size=size,
        chunk_overlap=40
    )
    chunks = splitter.split_documents(documents)
    print("Total Chunks:", len(chunks))
    data = []
    for i, chunk in enumerate(chunks):
        data.append({
            "Chunk Number": i + 1,
            "Character Count": len(chunk.page_content)
        })
    df = pd.DataFrame(data)
    print(df)
# Out:
# ...
#
# ...
# CHUNK SIZE = 200
# ...
# Total Chunks: 5
#    Chunk Number  Character Count
# 0             1              131
# 1             2              138
# 2             3              184
# 3             4              130
# 4             5               69
#
# ...
# CHUNK SIZE = 500
# ...
# Total Chunks: 2
#    Chunk Number  Character Count
# 0             1              455
# 1             2              200
#
# ...
# CHUNK SIZE = 1000
# ...
# Total Chunks: 1
#    Chunk Number  Character Count
# 0             1              656
