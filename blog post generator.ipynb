# %%
# !pip install groq
from groq import Groq
client = Groq(
    api_key="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"
)
topic = "Artificial Intelligence in Education"
step1_prompt = f"""
Generate a blog outline with 5 headings for the topic:
{topic}
"""
step1_response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {
            "role": "user",
            "content": step1_prompt
        }
    ],
    temperature=0.5,
    max_tokens=300
)
outline = step1_response.choices[0].message.content
print("=" * 70)
print("STEP 1 - BLOG OUTLINE")
print("=" * 70)
print(outline)
step2_prompt = f"""
Using the following outline, write 2 detailed paragraphs
for each heading.
Outline:
{outline}
"""
step2_response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {
            "role": "user",
            "content": step2_prompt
        }
    ],
    temperature=0.7,
    max_tokens=1500
)
body_content = step2_response.choices[0].message.content
print("\n")
print("=" * 70)
print("STEP 2 - BLOG BODY")
print("=" * 70)
print(body_content)
step3_prompt = f"""
Write:
1. A 3-sentence introduction
2. A 3-sentence conclusion
for a blog post on:
{topic}
"""
step3_response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {
            "role": "user",
            "content": step3_prompt
        }
    ],
    temperature=0.6,
    max_tokens=400
)
intro_conclusion = step3_response.choices[0].message.content
print("\n")
print("=" * 70)
print("STEP 3 - INTRODUCTION & CONCLUSION")
print("=" * 70)
print(intro_conclusion)
full_blog = f"""
BLOG TITLE: {topic}
{intro_conclusion}
{body_content}
"""
file_name = "ai_education_blog.txt"
with open(file_name, "w", encoding="utf-8") as file:
    file.write(full_blog)
print("\n")
print("=" * 70)
print("BLOG FILE CREATED")
print("=" * 70)
print(f"Blog saved as: {file_name}")
# Out:
# ...
# STEP 1 - BLOG OUTLINE
# ...
# Here is a blog outline with 5 headings on the topic "Artificial Intelligence in Education":
#
# **I. Introduction to AI in Education**
# * Brief overview of Artificial Intelligence (AI) and its growing presence in the education sector
# * Importance of AI in enhancing the learning experience and improving educational outcomes
#
# **II. Applications of AI in Education**
# * Overview of various AI-powered tools and technologies used in education, such as:
# 	+ Adaptive learning systems
# 	+ Intelligent tutoring systems
# 	+ Natural Language Processing (NLP) for language learning
# 	+ Automated grading and assessment systems
#
# **III. Benefits of AI in Education**
# * Discussion of the benefits of AI in education, including:
# 	+ Personalized learning experiences
# 	+ Increased efficiency and productivity for teachers
# 	+ Improved student outcomes and academic performance
# 	+ Enhanced accessibility and inclusivity for students with disabilities
#
# ...
