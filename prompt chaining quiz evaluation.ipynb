# %%
# !pip install groq
from groq import Groq
client = Groq(
    api_key="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"
)
topic = "Python lists"
step1_prompt = f"""
Generate 4 quiz questions about {topic}.
Keep the questions beginner friendly.
"""
step1_response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {
            "role": "user",
            "content": step1_prompt
        }
    ],
    temperature=0.5,
    max_tokens=300
)
quiz_questions = step1_response.choices[0].message.content
print("=" * 70)
print("STEP 1 - QUIZ QUESTIONS")
print("=" * 70)
print(quiz_questions)
step2_prompt = f"""
Generate detailed model answers for the following quiz questions:
{quiz_questions}
"""
step2_response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {
            "role": "user",
            "content": step2_prompt
        }
    ],
    temperature=0.5,
    max_tokens=600
)
model_answers = step2_response.choices[0].message.content
print("\n")
print("=" * 70)
print("STEP 2 - MODEL ANSWERS")
print("=" * 70)
print(model_answers)
student_answer = """
Python lists cannot store multiple values.
Lists are immutable.
append() removes elements from a list.
Lists use curly brackets {}.
"""
step3_prompt = f"""
You are a strict Python teacher.
Question and Model Answers:
{model_answers}
Student Answer:
{student_answer}
Give:
1. Score out of 10
2. Specific mistakes
3. Suggestions for improvement
"""
step3_response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {
            "role": "user",
            "content": step3_prompt
        }
    ],
    temperature=0.4,
    max_tokens=500
)
evaluation = step3_response.choices[0].message.content
print("\n")
print("=" * 70)
print("STEP 3 - STUDENT EVALUATION")
print("=" * 70)
print(evaluation)
# Out:
# ...
# STEP 1 - QUIZ QUESTIONS
# ...
# Here are four beginner-friendly quiz questions about Python lists:
#
# 1. What is the data type of the variable 'fruits' in the following code:
# fruits = ['apple', 'banana', 'cherry']?
# A) String
# B) Integer
# C) List
# D) Float
#
# Answer: C) List
#
# 2. How do you access the first element of a list in Python?
# A) list[1]
# B) list[0]
# C) list[-1]
# D) list['first']
#
# Answer: B) list[0]
#
# 3. What is the purpose of the 'append' method in a Python list?
# A) To remove the last element
# B) To add a new element at the beginning
# C) To add a new element at the end
# D) To sort the list
#
# Answer: C) To add a new element at the end
#
# 4. How do you create an empty list in Python?
# A) my_list = {}
# B) my_list = ()
# C) my_list = []
# D) my_list = ""
#
# Answer: C) my_list = []
#
#
# ...
# STEP 2 - MODEL ANSWERS
# ...
# Here are the detailed model answers for the given quiz questions about Python lists:
#
# ...
